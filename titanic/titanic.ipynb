# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

from statsmodels.nonparametric import kde, smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm
# Out:
# c:\ProgramData\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import sys

# %%
# Load the train and test datasets to create two DataFrames
train_url = "http://s3.amazonaws.com/assets.datacamp.com/course/Kaggle/train.csv"
test_url = "http://s3.amazonaws.com/assets.datacamp.com/course/Kaggle/test.csv"

df = pd.read_csv(train_url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df = df.drop(['Ticket', 'Cabin'], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 30            31         0       1
# ...

# %%
df['Sex'][df['Sex'] == 'male'] = 0
df['Sex'][df['Sex'] == 'female'] = 1
df
# Out:
# c:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# ...

# %%
df.Survived.value_counts()
# Out:
# 0    453
# 1    259
# Name: Sex, dtype: int64

# %%
df.Sex.value_counts()
# Out:
# 0    453
# 1    259
# Name: Sex, dtype: int64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(18, 6), dpi=1600)
# a = 0.2
# a_bar = 0.55

plt.subplot2grid((2, 3), (0, 0))              # plat many different shaped graphs together
df.Survived.value_counts().plot(kind='bar', alpha=0.55)   # plot a bar graph of those who survived and those who did not
plt.title('distribution of survival, ( 1= survived)')    # puts a title on our graph

plt.subplot2grid((2, 3), (0, 1))
plt.scatter(df.Survived, df.Age, alpha=0.2)
plt.ylabel('age')
plt.grid(b=True, which='major', axis='y')    # formats the grid line style of our graphs
plt.title('survival by age, (1=survived)')

# by kchan - survival by sex
plt.subplot2grid((2, 3), (0, 1))
plt.bar(df.Sex, df.Survived)
plt.ylabel('survival')
plt.xlabel('sex')
plt.title('survival by sex, (1=survived)')


plt.subplot2grid((2, 3), (0, 2))
df.Pclass.value_counts().plot(kind='barh', alpha=0.55)
plt.title('class distribution')

# plt.subplot2grid((2,3),(1,0), colspan=2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-62235a76a77d> in <module>()
#      18 # by kchan - survival by sex
#      19 plt.subplot2grid((2, 3), (0, 1))
# ---> 20 plt.bar(df.Sex, df.Survived)
#      21 plt.ylabel('survival')
#      22 plt.xlabel('sex')
#
# c:\ProgramData\Anaconda2\lib\site-packages\matplotlib\pyplot.py in bar(left, height, width, bottom, hold, data, **kwargs)
#    2702     try:
#    2703         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2704                      **kwargs)
#    2705     finally:
#    2706         ax._hold = washold
#
# c:\ProgramData\Anaconda2\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1895                     warnings.warn(msg % (label_namer, func.__name__),
#    1896                                   RuntimeWarning, stacklevel=2)
# ...
